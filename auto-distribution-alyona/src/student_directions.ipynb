# %% [markdown]
# Выявление набора направлений по данным для каждого студента, в проектах по которым он хотел бы участвовать.

# %%
import pandas as pd

# %%
df = pd.read_excel('data_with_score.xlsx')

# %%
df.columns
# Out:
# Index(['Отметка времени', 'Единая учетная запись СПбГУ (например, ST000000)',
#        'Выберете интересующие Вас роли, в  IT [Бизнес и системный анализ]',
#        'Выберете интересующие Вас роли, в  IT [Дизайн UX / UI и проектирование интерфейсов]',
#        'Выберете интересующие Вас роли, в  IT [Анализ и инженерия данных]',
#        'Выберете интересующие Вас роли, в  IT [Backend - разработка]',
#        'Выберете интересующие Вас роли, в  IT [Frontend - разработка]',
#        'Выберете интересующие Вас роли, в  IT [Тестирование и обеспечение качества]',
#        'Выберете интересующие Вас роли, в  IT [Развертывание и внедрение]',
#        'Выберете интересующие Вас роли, в  IT [Управление командой / проектом]',
#        'Выберете интересные для вас направление проекта (в направлении проекта могут быть все роли, указанные выше) [Разработка веб-сервисов (сайты, сервисы)]',
#        'Выберете интересные для вас направление проекта (в направлении проекта могут быть все роли, указанные выше) [Анализ текстов и поисковые движки]',
#        'Выберете интересные для вас направление проекта (в направлении проекта могут быть все роли, указанные выше) [Анализ изображений / видео]',
#        'Выберете интересные для вас направление проекта (в направлении проекта могут быть все роли, указанные выше) [Анализ временных рядов]',
#        'Выберете интересные для вас направление проекта (в направлении проекта могут быть все роли, указанные выше) [Анализ табличных данных]',
#        'Выберете интересные для вас направление проекта (в направлении проекта могут быть все роли, указанные выше) [Робототехника (оборудование, теория управления, техническое зрение, интерфейсы)]',
#        'Выберете интересные для вас направление проекта (в направлении проекта могут быть все роли, указанные выше) [Gamedev]',
#        'Если в предыдущем вопросе для Вас не было интересного направления деятельности, расскажите нам об области, в которой Вы хотите развиваться',
#        'Если Вы уже работаете над интересным проектом или успешно завершили - опишите, что это за проект и свою роль в нем (можете добавить ссылку на репозиторий)',
#        'Оцените Ваши знания в области IT [Парадигмы программирования (ООП, функциональное, аспектно-ориентированное, и др.)]',
#        'Оцените Ваши знания в области IT [Архитектура ПО]',
#        'Оцените Ваши знания в области IT [Паттерны проектирования]',
#        'Оцените Ваши знания в области IT [Протоколы коммуникаций (REST, gRPC, и др.)]',
#        'Оцените Ваши знания в области IT [Алгоритмы и структуры данных]',
#        'Оцените Ваши знания в области IT [Потоки и параллельность]',
#        'Оцените Ваши знания в области IT [Linux in dev and administration]',
#        'Оцените Ваши знания в области IT [Windows in dev and administration]',
#        'Оцените Ваши знания в области IT [Проектирование и оптимизация баз данных]',
#        'Оцените Ваши знания в области IT [Data Science and Machine Learning]',
#        'Какими еще знаниями Вы владеете, релевантными для IT-отрасли и в какой степени? Перечислите их и оцените',
#        'Языки программирования (например: C++, Python, Java, etc)',
#        'Библиотеки и фреймворки для различных направлений использования (например: Qt, Numpy, Weka, Angular, PyTorch, etc)',
#        'Инструменты для проектирования, бизнес и системного анализа (например: BPMN, UML, Archimate, ARIS etc)',
#        'Инструменты для разработки ПО - например: VS Code, PyCharm, Git, etc)',
#        'Инструменты для тестирования  (например: GTests, Selenium, Gatling, pytest etc)',
#        'Инструменты CI / CD (например: Jenkins, Travis CI, Docker, etc)',
#        'Инструменты для управления проектами (например: Jira, Trello, MS Project, etc) ',
#        'Аналитические навыки [Поиск информации (научные статьи, документация)]',
#        'Аналитические навыки [Сбор и анализ требований к ПО]',
#        'Аналитические навыки [Декомпозиция задач]',
#        'Аналитические навыки [Планирование своей и чужой деятельности]',
#        'Аналитические навыки [Тестирование]',
#        'Аналитические навыки [Ведение документации]',
#        'SoftSkills [Self management]', 'SoftSkills [Коммуникации]',
#        'SoftSkills [Работа в команде]', 'SoftSkills [Наставничество]',
#        'SoftSkills [Управление людьми]',
#        'Какими еще навыками в области IT Вы обладаете? Оцените данные навыки',
#        'Оцените Ваш уровень мотивации [К работе над интересными проектами]',
#        'Оцените Ваш уровень мотивации [Определить свой путь дальнейшего развития и развиваться в IT]',
#        'Оцените Ваш уровень мотивации [Устроиться на интересную для себя работу]',
#        'Хотите ли Вы общаться с другими студентами и выпускниками, заинтересованными в развитии в области IT на базе СПбГУ на интересующие Вас темы?',
#        'Что Вам поможет развиваться быстрее в том направлении деятельности, которое Вы выбрали?',
#        'Year', 'Season', 'score', 'hard_skills_score', 'soft_skills_score',
#        'analytics_skills_score', 'knowladges_skills_score'],
#       dtype='object')

# %%
directions = {'Выберете интересные для вас направление проекта (в направлении проекта могут быть все роли, указанные выше) [Разработка веб-сервисов (сайты, сервисы)]' : 'Web',
              'Выберете интересные для вас направление проекта (в направлении проекта могут быть все роли, указанные выше) [Анализ текстов и поисковые движки]' : 'NLP',
              'Выберете интересные для вас направление проекта (в направлении проекта могут быть все роли, указанные выше) [Анализ изображений / видео]': 'CV',
              'Выберете интересные для вас направление проекта (в направлении проекта могут быть все роли, указанные выше) [Анализ временных рядов]': 'Time Series',
              'Выберете интересные для вас направление проекта (в направлении проекта могут быть все роли, указанные выше) [Анализ табличных данных]' :  'DS',
              'Выберете интересные для вас направление проекта (в направлении проекта могут быть все роли, указанные выше) [Робототехника (оборудование, теория управления, техническое зрение, интерфейсы)]': 'Robotics',
              'Выберете интересные для вас направление проекта (в направлении проекта могут быть все роли, указанные выше) [Gamedev]' : 'GameDev',
              'Если в предыдущем вопросе для Вас не было интересного направления деятельности, расскажите нам об области, в которой Вы хотите развиваться': 'Other'}

# %%
other  = { 'Разработка android приложений' : ['Mobile Development'],
           'Звуковой анализ (спектральный, кепстральный), разработка музыкального программного обеспечения, разработка всевозможных мобильных приложений под iOS/iPadOS на Swift, разработка всевозможных приложений и информационных систем под macOS на Swift' : ['Mobile Development', 'DS'],
           'STT, TTS' : ['DS'],
           'Мультиагентные системы и обучение с подкреплением. Генетические алгоритмы' : ['DS'],
           'К первому вопросу: работаю продуктовым аналитиком, потому интересен анализ данных и взаимодействия с пользователями с применением ключевых метрик.' : ['Data Analysis'],
           'Области интересные, но также хотчу добавить Мобильную Разработку' : ['Mobile Development'],
           'android разработка' : ['Mobile Development'], 
           'Data analysis, engineering' : ['Data Analysis', 'Data Engeneering'],
           'Промышленная роботехника и применение нейросетей для задач точного измерения' : ['Robotics'],
           'Анализ речи. Звуковые данные' : ['DS','Data Analysis'],
           'Дополнительно к предыдущему - цифровая обработка сигналов': ['DS'],
           'Разработка мобильных приложений под android' : ['Mobile Development'],
           'Data engineer' : ['Data Engeneering'],
           'Мобильная разработка (Android, Kotlin Multiplatform)' : ['Mobile Development'],
           'Разработка API (django, fastapi...)' : ['API'],
           'Биоинформатика, анализ биологических данных' : ['DS','Data Analysis'],
           'Мобильная Разработка Android IOS Flutter' : ['Mobile Development'],
           'Меня интересует цифровая схемотехника, архитектура компьютера' : ['low_level development'],
           'Пентест; системное программирование; проектирование программного обеспечения.' : ['low_level development'],
           'Аналитик данных' : ['Data Analysis'],
           'Хочу развиваться в области анализа данных,за лето разобрался с основами и планирую закрепить изученное и  получить опыт и новые знания в учебной практике' : ['Data Analysis'],
           'Нарративный дизайнер' : ['Design'],
           'Android разработка' : ['Mobile Development'],
           'Глубокое обучение' : ['DL'],
           'Очень хочу развиваться в сфере дизайна' : ['Design'],
           'В дополнение к вебу - мобильная разработка. \nХотелось бы уделить больше времени не рутинной реализации, а продумыванию оптимальной архитектуры, удобных интерфейсов и внутрикомандного взаимодействия.' : ['Mobile Development'],
           'Хотел бы писать полезные людям приложения под iOS, MacOS, AppleWatch и под остальные девайсы Apple. Под полезными подразумеваю: помощь в жизни, продуктивности, в лайф-стайле и тд. Не уверен что сверху мог где-то это отметить.' : ['Mobile Development'],
           'Системное программирование (под linux), низкоуровневое программирование' : ['low_level development'],
           'В предыдущих вопросах использовал "не знаком" как "не против". В анализе только в качестве визуализации.\n\nВообще чем-то в районе инструментов визуального программирования я бы занялся.' : ['Data Analysis'],
           'Хотела попробовать себя в сферах связанных с медициной и биологией, так как мне достаточно интересны гематология и генетика. Также моя выпускная работа будет скорее всего связана с медико-биологической статистикой. Но также было бы интересно попробовать себя и в других направлениях.' : ['Data Analysis'],
           'Компьютерная графика, разработка языков программирования' : ['Design', 'programming language development'],
           None : ''
}

# %%
df
# Out:
#             Отметка времени Единая учетная запись СПбГУ (например, ST000000)  \
# 0   2023-10-07 16:02:10.676                                         ST110311
# 1   2023-10-02 16:23:02.340                                         ST063118
# 2   2023-09-15 19:00:59.596                                         ST114946
# 3   2023-09-11 14:35:19.227                                         ST112047
# 4   2023-09-10 22:04:15.396                                         ST112471
# ..                      ...                                              ...
# 344 2019-08-26 11:39:44.782                                         ST061362
# 345 2019-08-26 11:38:34.578                                         ST061177
# 346 2019-08-26 11:37:09.651                                         ST054461
# 347 2019-08-26 11:36:51.336                                         ST063110
# 348 2019-08-26 11:34:08.637                                         ST064738
#
#      Выберете интересующие Вас роли, в  IT [Бизнес и системный анализ]  \
# 0                                                    3
# 1                                                    1
# 2                                                    1
# 3                                                    3
# 4                                                    1
# ..                                                 ...
# 344                                                  4
# 345                                                  1
# 346                                                  1
# 347                                                  1
# 348                                                  4
#
#      Выберете интересующие Вас роли, в  IT [Дизайн UX / UI и проектирование интерфейсов]  \
# 0                                                    1
# 1                                                    3
# 2                                                    3
# 3                                                    3
# 4                                                    1
# ..                                                 ...
# 344                                                  5
# 345                                                  5
# 346                                                  5
# 347                                                  2
# 348                                                  4
#
#      Выберете интересующие Вас роли, в  IT [Анализ и инженерия данных]  \
# 0                                                  1.0
# 1                                                  1.0
# 2                                                  1.0
# 3                                                  3.0
# 4                                                  1.0
# ..                                                 ...
# 344                                                NaN
# 345                                                NaN
# 346                                                NaN
# 347                                                NaN
# 348                                                NaN
#
#      Выберете интересующие Вас роли, в  IT [Backend - разработка]  \
# 0                                                    1
# 1                                                    5
# 2                                                    3
# 3                                                    1
# 4                                                    1
# ..                                                 ...
# 344                                                  1
# 345                                                  4
# 346                                                  4
# 347                                                  4
# 348                                                  1
#
#      Выберете интересующие Вас роли, в  IT [Frontend - разработка]  \
# 0                                                    1
# 1                                                    3
# 2                                                    5
# 3                                                    1
# 4                                                    1
# ..                                                 ...
# 344                                                  1
# 345                                                  4
# 346                                                  4
# 347                                                  4
# 348                                                  1
#
#      Выберете интересующие Вас роли, в  IT [Тестирование и обеспечение качества]  \
# 0                                                    3
# 1                                                    3
# 2                                                    3
# 3                                                    3
# 4                                                    3
# ..                                                 ...
# 344                                                  2
# 345                                                  1
# 346                                                  2
# 347                                                  4
# 348                                                  1
#
#      Выберете интересующие Вас роли, в  IT [Развертывание и внедрение]  \
# 0                                                    1
# 1                                                    3
# 2                                                    1
# 3                                                    1
# 4                                                    1
# ..                                                 ...
# 344                                                  2
# 345                                                  2
# 346                                                  2
# 347                                                  2
# 348                                                  1
#
#      Выберете интересующие Вас роли, в  IT [Управление командой / проектом]  \
# 0                                                    3
# 1                                                    3
# 2                                                    1
# 3                                                    5
# 4                                                    5
# ..                                                 ...
# 344                                                  5
# 345                                                  2
# 346                                                  2
# 347                                                  1
# 348                                                  4
#
#      ...  \
# 0    ...
# 1    ...
# 2    ...
# 3    ...
# 4    ...
# ..   ...
# 344  ...
# 345  ...
# 346  ...
# 347  ...
# 348  ...
#
#      Оцените Ваш уровень мотивации [Устроиться на интересную для себя работу]  \
# 0                                                    3
# 1                                                    4
# 2                                                    3
# 3                                                    6
# 4                                                    1
# ..                                                 ...
# 344                                                  6
# 345                                                  3
# 346                                                  6
# 347                                                  6
# 348                                                  4
#
#      Хотите ли Вы общаться с другими студентами и выпускниками, заинтересованными в развитии в области IT на базе СПбГУ на интересующие Вас темы?  \
# 0                                                    2
# 1                                                    1
# 2                                                    2
# 3                                                    1
# 4                                                    1
# ..                                                 ...
# 344                                                  1
# 345                                                  1
# 346                                                  1
# 347                                                  1
# 348                                                  2
#
#      Что Вам поможет развиваться быстрее в том направлении деятельности, которое Вы выбрали?  \
# 0                                                  NaN
# 1                Опытные наставники, интересные задачи
# 2                                Чёткий план действий
# 3    Прежний опыт в написанию проектов и любовь к р...
# 4                                          Личный рост
# ..                                                 ...
# 344  Время для развития навыков\nВозможность общать...
# 345                                                NaN
# 346                         Чётко поставленные задачи
# 347  Считаю, что интересная, хорошо выстроенная задача
# 348                                                NaN
#
#      Year  Season  score  hard_skills_score soft_skills_score  \
# 0    2023   Осень   10.1                1.2               4.6
# 1    2023   Осень   13.7                2.2               3.4
# 2    2023   Осень   13.7                2.5               3.6
# 3    2023   Осень   10.8                1.0               5.0
# 4    2023   Осень   11.3                0.0               4.6
# ..    ...     ...    ...                ...               ...
# 344  2019   Осень   11.4                2.6               2.4
# 345  2019   Осень    7.0                1.7               1.8
# 346  2019   Осень   11.0                1.8               2.2
# 347  2019   Осень    9.1                2.0               1.6
# 348  2019   Осень    6.6                1.2               1.6
#
#     analytics_skills_score  knowladges_skills_score
# 0                      3.3                      1.0
# 1                      4.2                      3.9
# 2                      4.5                      3.1
# 3                      3.7                      1.1
# 4                      4.8                      1.9
# ..                     ...                      ...
# 344                    3.5                      2.9
# 345                    1.7                      1.8
# 346                    4.0                      3.0
# 347                    2.7                      2.8
# 348                    2.3                      1.5
#
# [349 rows x 61 columns]

# %%
def students_directions(df, directions, other):
   data = df
   data['directions'] = [[] for _ in range(len(data))]
   directions_columns = list(directions.keys())
   new_columns = list(directions.values())
   directions_columns.append('Единая учетная запись СПбГУ (например, ST000000)')
   directions_columns.append('Year')
   df_directions = data[directions_columns]
   students = []
   df_directions.rename(columns=directions, inplace=True)
   df_directions = df_directions.fillna(0)  
   df_directions['Other'] = df_directions['Other'].map(other) 
   df_directions['Other'] = df_directions['Other'].fillna('0')  
   df_directions = df_directions.reset_index()

   for index, student_df in df_directions.iterrows():
      student = dict()
      student['st'] = student_df['Единая учетная запись СПбГУ (например, ST000000)'] 
      student['year'] = student_df['Year'] 
      student['directions'] = []
      for column in new_columns:
         if column != 'Other' and int(student_df[column]) > 1:
            student['directions'].append(column)
         if column == 'Other' and student_df['Other'] != '0':
            for d in student_df['Other']:
               student['directions'].append(d)
      data.at[index, 'directions'] = student['directions']
      students.append(student)

   return data, students

# %%
data, students = students_directions(df, directions, other)
# Out:
# C:\Users\Alyonka\AppData\Local\Temp\ipykernel_23984\1048672533.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_directions.rename(columns=directions, inplace=True)

# %%
data
# Out:
#             Отметка времени Единая учетная запись СПбГУ (например, ST000000)  \
# 0   2023-10-07 16:02:10.676                                         ST110311
# 1   2023-10-02 16:23:02.340                                         ST063118
# 2   2023-09-15 19:00:59.596                                         ST114946
# 3   2023-09-11 14:35:19.227                                         ST112047
# 4   2023-09-10 22:04:15.396                                         ST112471
# ..                      ...                                              ...
# 344 2019-08-26 11:39:44.782                                         ST061362
# 345 2019-08-26 11:38:34.578                                         ST061177
# 346 2019-08-26 11:37:09.651                                         ST054461
# 347 2019-08-26 11:36:51.336                                         ST063110
# 348 2019-08-26 11:34:08.637                                         ST064738
#
#      Выберете интересующие Вас роли, в  IT [Бизнес и системный анализ]  \
# 0                                                    3
# 1                                                    1
# 2                                                    1
# 3                                                    3
# 4                                                    1
# ..                                                 ...
# 344                                                  4
# 345                                                  1
# 346                                                  1
# 347                                                  1
# 348                                                  4
#
#      Выберете интересующие Вас роли, в  IT [Дизайн UX / UI и проектирование интерфейсов]  \
# 0                                                    1
# 1                                                    3
# 2                                                    3
# 3                                                    3
# 4                                                    1
# ..                                                 ...
# 344                                                  5
# 345                                                  5
# 346                                                  5
# 347                                                  2
# 348                                                  4
#
#      Выберете интересующие Вас роли, в  IT [Анализ и инженерия данных]  \
# 0                                                  1.0
# 1                                                  1.0
# 2                                                  1.0
# 3                                                  3.0
# 4                                                  1.0
# ..                                                 ...
# 344                                                NaN
# 345                                                NaN
# 346                                                NaN
# 347                                                NaN
# 348                                                NaN
#
#      Выберете интересующие Вас роли, в  IT [Backend - разработка]  \
# 0                                                    1
# 1                                                    5
# 2                                                    3
# 3                                                    1
# 4                                                    1
# ..                                                 ...
# 344                                                  1
# 345                                                  4
# 346                                                  4
# 347                                                  4
# 348                                                  1
#
#      Выберете интересующие Вас роли, в  IT [Frontend - разработка]  \
# 0                                                    1
# 1                                                    3
# 2                                                    5
# 3                                                    1
# 4                                                    1
# ..                                                 ...
# 344                                                  1
# 345                                                  4
# 346                                                  4
# 347                                                  4
# 348                                                  1
#
#      Выберете интересующие Вас роли, в  IT [Тестирование и обеспечение качества]  \
# 0                                                    3
# 1                                                    3
# 2                                                    3
# 3                                                    3
# 4                                                    3
# ..                                                 ...
# 344                                                  2
# 345                                                  1
# 346                                                  2
# 347                                                  4
# 348                                                  1
#
#      Выберете интересующие Вас роли, в  IT [Развертывание и внедрение]  \
# 0                                                    1
# 1                                                    3
# 2                                                    1
# 3                                                    1
# 4                                                    1
# ..                                                 ...
# 344                                                  2
# 345                                                  2
# 346                                                  2
# 347                                                  2
# 348                                                  1
#
#      Выберете интересующие Вас роли, в  IT [Управление командой / проектом]  \
# 0                                                    3
# 1                                                    3
# 2                                                    1
# 3                                                    5
# 4                                                    5
# ..                                                 ...
# 344                                                  5
# 345                                                  2
# 346                                                  2
# 347                                                  1
# 348                                                  4
#
#      ...  \
# 0    ...
# 1    ...
# 2    ...
# 3    ...
# 4    ...
# ..   ...
# 344  ...
# 345  ...
# 346  ...
# 347  ...
# 348  ...
#
#      Хотите ли Вы общаться с другими студентами и выпускниками, заинтересованными в развитии в области IT на базе СПбГУ на интересующие Вас темы?  \
# 0                                                    2
# 1                                                    1
# 2                                                    2
# 3                                                    1
# 4                                                    1
# ..                                                 ...
# 344                                                  1
# 345                                                  1
# 346                                                  1
# 347                                                  1
# 348                                                  2
#
#      Что Вам поможет развиваться быстрее в том направлении деятельности, которое Вы выбрали?  \
# 0                                                  NaN
# 1                Опытные наставники, интересные задачи
# 2                                Чёткий план действий
# 3    Прежний опыт в написанию проектов и любовь к р...
# 4                                          Личный рост
# ..                                                 ...
# 344  Время для развития навыков\nВозможность общать...
# 345                                                NaN
# 346                         Чётко поставленные задачи
# 347  Считаю, что интересная, хорошо выстроенная задача
# 348                                                NaN
#
#      Year  Season  score  hard_skills_score  soft_skills_score  \
# 0    2023   Осень   10.1                1.2                4.6
# 1    2023   Осень   13.7                2.2                3.4
# 2    2023   Осень   13.7                2.5                3.6
# 3    2023   Осень   10.8                1.0                5.0
# 4    2023   Осень   11.3                0.0                4.6
# ..    ...     ...    ...                ...                ...
# 344  2019   Осень   11.4                2.6                2.4
# 345  2019   Осень    7.0                1.7                1.8
# 346  2019   Осень   11.0                1.8                2.2
# 347  2019   Осень    9.1                2.0                1.6
# 348  2019   Осень    6.6                1.2                1.6
#
#     analytics_skills_score knowladges_skills_score  \
# 0                      3.3                     1.0
# 1                      4.2                     3.9
# 2                      4.5                     3.1
# 3                      3.7                     1.1
# 4                      4.8                     1.9
# ..                     ...                     ...
# 344                    3.5                     2.9
# 345                    1.7                     1.8
# 346                    4.0                     3.0
# 347                    2.7                     2.8
# 348                    2.3                     1.5
#
#                                     directions
# 0                                   [Web, NLP]
# 1                  [Time Series, DS, Robotics]
# 2                                     [CV, DS]
# 3                         [Web, NLP, Robotics]
# 4                                           []
# ..                                         ...
# 344                  [Time Series, DS, Design]
# 345                [Web, NLP, Time Series, DS]
# 346           [NLP, Time Series, DS, Robotics]
# 347  [Web, NLP, Time Series, DS, Robotics, DL]
# 348                [Web, NLP, Time Series, DS]
#
# [349 rows x 62 columns]

# %%
students
# Out:
# [{'st': 'ST110311', 'year': 2023, 'directions': ['Web', 'NLP']},
#  {'st': 'ST063118',
#   'year': 2023,
#   'directions': ['Time Series', 'DS', 'Robotics']},
#  {'st': 'ST114946', 'year': 2023, 'directions': ['CV', 'DS']},
#  {'st': 'ST112047', 'year': 2023, 'directions': ['Web', 'NLP', 'Robotics']},
#  {'st': 'ST112471', 'year': 2023, 'directions': []},
#  {'st': 'ST069808',
#   'year': 2023,
#   'directions': ['Web', 'CV', 'Time Series', 'Robotics']},
#  {'st': 'ST068144', 'year': 2023, 'directions': ['NLP', 'GameDev']},
#  {'st': 'ST110974',
#   'year': 2023,
#   'directions': ['Web', 'CV', 'DS', 'Robotics']},
#  {'st': 'ST110167', 'year': 2023, 'directions': ['CV']},
#  {'st': 'ST115982',
#   'year': 2023,
#   'directions': ['CV', 'Time Series', 'DS', 'Robotics']},
#  {'st': 'ST089558',
#   'year': 2023,
#   'directions': ['Web', 'CV', 'DS', 'GameDev']},
#  {'st': 'ST112784',
#   'year': 2023,
#   'directions': ['Web', 'CV', 'Time Series', 'DS', 'Robotics']},
#  {'st': 'ST110277',
#   'year': 2023,
#   'directions': ['Web', 'NLP', 'CV', 'GameDev']},
#  {'st': 'ST089430', 'year': 2023, 'directions': ['Web', 'Robotics']},
#  {'st': 'ST110470', 'year': 2023, 'directions': ['CV', 'Time Series']},
#  {'st': 'ST110496', 'year': 2023, 'directions': ['Robotics']},
#  {'st': 'ST077125', 'year': 2023, 'directions': ['Time Series', 'Robotics']},
#  {'st': 'ST090662',
#   'year': 2023,
#   'directions': ['Web', 'CV', 'Time Series', 'GameDev']},
#  {'st': 'ST112436',
#   'year': 2023,
#   'directions': ['Web', 'NLP', 'CV', 'Time Series', 'DS', 'GameDev']},
#  {'st': 'ST115985',
#   'year': 2023,
#   'directions': ['NLP', 'CV', 'Time Series', 'DS', 'GameDev']},
#  {'st': 'ST095296', 'year': 2023, 'directions': ['NLP']},
#  {'st': 'ST068744', 'year': 2023, 'directions': ['DS']},
#  {'st': 'ST069290', 'year': 2023, 'directions': ['DS']},
#  {'st': 'ST069191', 'year': 2023, 'directions': ['DS']},
#  {'st': 'ST068916', 'year': 2023, 'directions': ['Web', 'NLP', 'CV']},
#  {'st': 'ST106381',
#   'year': 2023,
#   'directions': ['Web', 'NLP', 'CV', 'GameDev']},
#  {'st': 'ST095279', 'year': 2023, 'directions': []},
#  {'st': 'ST062087', 'year': 2023, 'directions': ['CV', 'DS', 'Robotics']},
#  {'st': 'ST095278',
#   'year': 2023,
#   'directions': ['Web',
#    'NLP',
#    'CV',
#    'Time Series',
#    'DS',
#    'Robotics',
#    'GameDev']},
#  {'st': 'ST105895', 'year': 2023, 'directions': ['NLP', 'CV', 'DS']},
#  {'st': 'ST103420',
#   'year': 2023,
#   'directions': ['Web', 'NLP', 'CV', 'GameDev']},
#  {'st': 'ST069636', 'year': 2023, 'directions': ['Time Series', 'DS']},
#  {'st': 'ST115983',
#   'year': 2023,
#   'directions': ['Web',
#    'NLP',
#    'CV',
#    'Time Series',
#    'DS',
#    'Robotics',
#    'GameDev']},
#  {'st': 'ST095297', 'year': 2023, 'directions': ['Web', 'CV', 'DS']},
#  {'st': 'ST086871', 'year': 2023, 'directions': ['CV']},
#  {'st': 'ST095286', 'year': 2023, 'directions': ['NLP']},
#  {'st': 'ST095276', 'year': 2023, 'directions': ['Web', 'NLP', 'CV']},
#  {'st': 'ST069505',
#   'year': 2023,
#   'directions': ['Web', 'NLP', 'Time Series', 'DS', 'DS']},
#  {'st': 'ST095277', 'year': 2023, 'directions': ['Web', 'CV', 'Robotics']},
#  {'st': 'ST076784', 'year': 2023, 'directions': []},
#  {'st': 'ST068359',
#   'year': 2023,
#   'directions': ['NLP', 'CV', 'Time Series', 'DS']},
#  {'st': 'ST102619', 'year': 2023, 'directions': []},
#  {'st': 'ST094235', 'year': 2023, 'directions': ['Web', 'NLP', 'CV', 'DS']},
#  {'st': 'ST112163',
#   'year': 2023,
#   'directions': ['Web',
#    'NLP',
#    'CV',
#    'Time Series',
#    'DS',
#    'Robotics',
#    'GameDev']},
#  {'st': 'ST112193',
#   'year': 2023,
#   'directions': ['NLP', 'Time Series', 'GameDev']},
#  {'st': 'ST097831', 'year': 2023, 'directions': ['NLP', 'GameDev']},
#  {'st': 'ST067854',
#   'year': 2023,
#   'directions': ['Web', 'CV', 'Time Series', 'DS']},
#  {'st': 'ST115981',
#   'year': 2023,
#   'directions': ['CV', 'Time Series', 'DS', 'Mobile Development', 'DS']},
#  {'st': 'ST115987', 'year': 2023, 'directions': ['NLP', 'CV', 'GameDev']},
#  {'st': 'ST113210', 'year': 2023, 'directions': ['Web', 'Time Series', 'DS']},
#  {'st': 'ST113273', 'year': 2023, 'directions': []},
#  {'st': 'ST105896', 'year': 2023, 'directions': ['GameDev']},
#  {'st': 'ST095282',
#   'year': 2023,
#   'directions': ['DS', 'Robotics', 'Mobile Development']},
#  {'st': 'ST073575', 'year': 2023, 'directions': ['Web', 'CV']},
#  {'st': 'ST110348', 'year': 2023, 'directions': ['NLP', 'CV']},
#  {'st': 'ST094241', 'year': 2023, 'directions': ['CV']},
#  {'st': 'ST115978', 'year': 2023, 'directions': []},
#  {'st': 'ST064151',
#   'year': 2023,
#   'directions': ['Web', 'NLP', 'CV', 'Time Series']},
#  {'st': 'ST095280', 'year': 2023, 'directions': ['CV', 'Robotics', 'GameDev']},
#  {'st': 'ST115988', 'year': 2023, 'directions': ['Web', 'CV', 'Robotics']},
#  {'st': 'ST110625',
#   'year': 2023,
#   'directions': ['NLP', 'CV', 'Time Series', 'DS', 'Robotics']},
#  {'st': 'ST110976', 'year': 2023, 'directions': ['DS', 'GameDev']},
#  {'st': 'ST069378', 'year': 2023, 'directions': ['NLP', 'Time Series', 'DS']},
#  {'st': 'ST115977', 'year': 2023, 'directions': ['NLP', 'CV', 'DS']},
#  {'st': 'ST072069', 'year': 2023, 'directions': ['NLP', 'CV']},
#  {'st': 'ST115984', 'year': 2023, 'directions': ['CV', 'GameDev']},
#  {'st': 'ST110105',
#   'year': 2023,
#   'directions': ['Web',
#    'NLP',
#    'CV',
#    'Time Series',
#    'DS',
#    'Robotics',
#    'GameDev']},
#  {'st': 'ST068048', 'year': 2023, 'directions': []},
#  {'st': 'ST110124', 'year': 2023, 'directions': ['NLP', 'Time Series']},
#  {'st': 'ST068737', 'year': 2023, 'directions': ['NLP', 'CV', 'GameDev']},
#  {'st': 'ST094236',
#   'year': 2023,
#   'directions': ['Web',
#    'NLP',
#    'CV',
#    'Time Series',
#    'DS',
#    'Robotics',
#    'GameDev']},
#  {'st': 'ST068452', 'year': 2023, 'directions': ['NLP', 'Time Series', 'DS']},
#  {'st': 'ST097589',
#   'year': 2023,
#   'directions': ['NLP', 'CV', 'Time Series', 'Robotics']},
#  {'st': 'ST095275',
#   'year': 2023,
#   'directions': ['Web', 'NLP', 'CV', 'Robotics']},
#  {'st': 'ST095292',
#   'year': 2023,
#   'directions': ['Web', 'NLP', 'Time Series', 'Robotics']},
#  {'st': 'ST068246',
#   'year': 2023,
#   'directions': ['NLP', 'CV', 'DS', 'Robotics', 'GameDev']},
#  {'st': 'ST095294', 'year': 2023, 'directions': ['CV', 'DS']},
#  {'st': 'ST095287', 'year': 2023, 'directions': ['NLP', 'CV']},
#  {'st': 'ST095273', 'year': 2023, 'directions': ['NLP', 'CV']},
#  {'st': 'ST069557', 'year': 2023, 'directions': ['GameDev']},
#  {'st': 'ST095293', 'year': 2023, 'directions': ['NLP', 'Time Series']},
#  {'st': 'ST069751', 'year': 2023, 'directions': ['Web', 'Time Series', 'DS']},
#  {'st': 'ST068068', 'year': 2023, 'directions': ['CV']},
#  {'st': 'ST068010',
#   'year': 2023,
#   'directions': ['Web', 'Time Series', 'GameDev']},
#  {'st': 'ST106375',
#   'year': 2023,
#   'directions': ['NLP', 'CV', 'Time Series', 'DS']},
#  {'st': 'ST068863',
#   'year': 2023,
#   'directions': ['Web', 'CV', 'Time Series', 'DS']},
#  {'st': 'ST115979', 'year': 2023, 'directions': ['DS', 'GameDev']},
#  {'st': 'ST110863', 'year': 2023, 'directions': ['Web', 'NLP', 'Time Series']},
#  {'st': 'ST087880',
#   'year': 2023,
#   'directions': ['Web',
#    'NLP',
#    'CV',
#    'Time Series',
#    'DS',
#    'Robotics',
#    'GameDev']},
#  {'st': 'ST087238',
#   'year': 2023,
#   'directions': ['Web', 'NLP', 'Time Series', 'DS', 'GameDev']},
#  {'st': 'ST086937', 'year': 2023, 'directions': ['Web', 'CV', 'DS']},
#  {'st': 'ST087059', 'year': 2023, 'directions': ['Web', 'CV', 'DS']},
#  {'st': 'ST086935',
#   'year': 2023,
#   'directions': ['Web', 'NLP', 'Time Series', 'Robotics']},
#  {'st': 'ST088132',
#   'year': 2023,
#   'directions': ['Web',
#    'NLP',
#    'CV',
#    'Time Series',
#    'DS',
#    'Robotics',
#    'GameDev']},
#  {'st': 'ST087794', 'year': 2023, 'directions': ['NLP', 'CV']},
#  {'st': 'ST087265', 'year': 2023, 'directions': ['NLP', 'CV', 'DS']},
#  {'st': 'ST087992', 'year': 2023, 'directions': ['Web', 'NLP', 'CV', 'DS']},
#  {'st': 'ST084859',
#   'year': 2023,
#   'directions': ['Web', 'NLP', 'CV', 'Time Series', 'DS', 'Robotics']},
#  {'st': 'ST087948',
#   'year': 2023,
#   'directions': ['Time Series', 'DS', 'Robotics', 'DS', 'Data Analysis']},
#  {'st': 'ST087040', 'year': 2023, 'directions': ['NLP', 'GameDev']},
#  {'st': 'ST087920', 'year': 2023, 'directions': ['DS', 'Robotics', 'GameDev']},
#  {'st': 'ST084445', 'year': 2023, 'directions': ['NLP', 'CV', 'DS']},
#  {'st': 'ST034767', 'year': 2023, 'directions': ['Web', 'DS']},
#  {'st': 'ST087263', 'year': 2023, 'directions': ['GameDev']},
#  {'st': 'ST087034', 'year': 2023, 'directions': ['NLP', 'Time Series', 'DS']},
#  {'st': 'ST087322', 'year': 2023, 'directions': ['Web', 'DS', 'Robotics']},
#  {'st': 'ST086888', 'year': 2023, 'directions': ['Robotics']},
#  {'st': 'ST087640', 'year': 2023, 'directions': ['CV', 'DS', 'GameDev']},
#  {'st': 'ST087415',
#   'year': 2023,
#   'directions': ['NLP', 'Robotics', 'GameDev']},
#  {'st': 'ST087204',
#   'year': 2023,
#   'directions': ['Data Analysis', 'Data Engeneering']},
#  {'st': 'ST087812', 'year': 2023, 'directions': []},
#  {'st': 'ST089228',
#   'year': 2023,
#   'directions': ['Web', 'DS', 'Mobile Development']},
#  {'st': 'ST083948',
#   'year': 2023,
#   'directions': ['Time Series', 'DS', 'Robotics', 'Mobile Development']},
#  {'st': 'ST086858', 'year': 2023, 'directions': ['NLP', 'Time Series']},
#  {'st': 'ST087940',
#   'year': 2023,
#   'directions': ['Web', 'CV', 'Data Analysis']},
#  {'st': 'ST087126',
#   'year': 2023,
#   'directions': ['NLP', 'Robotics', 'GameDev']},
#  {'st': 'ST087793', 'year': 2023, 'directions': ['Web']},
#  {'st': 'ST086961',
#   'year': 2023,
#   'directions': ['NLP', 'Robotics', 'GameDev']},
#  {'st': 'ST101960',
#   'year': 2022,
#   'directions': ['NLP', 'Robotics', 'GameDev']},
#  {'st': 'ST089430',
#   'year': 2022,
#   'directions': ['Web', 'NLP', 'Time Series', 'DS']},
#  {'st': 'ST087517', 'year': 2022, 'directions': ['Web', 'NLP', 'CV']},
#  {'st': 'ST068916', 'year': 2022, 'directions': ['DS']},
#  {'st': 'ST063112', 'year': 2022, 'directions': ['Web', 'NLP', 'DS']},
#  {'st': 'ST086980', 'year': 2022, 'directions': ['Web', 'DS']},
#  {'st': 'ST067886',
#   'year': 2022,
#   'directions': ['NLP', 'CV', 'Time Series', 'GameDev']},
#  {'st': 'ST054703',
#   'year': 2022,
#   'directions': ['Web',
#    'NLP',
#    'CV',
#    'Time Series',
#    'DS',
#    'Robotics',
#    'GameDev',
#    'DS']},
#  {'st': 'ST073936', 'year': 2022, 'directions': ['Time Series']},
#  {'st': 'ST087448', 'year': 2022, 'directions': ['Time Series']},
#  {'st': 'ST089558',
#   'year': 2022,
#   'directions': ['Web', 'CV', 'DS', 'GameDev']},
#  {'st': 'ST088117', 'year': 2022, 'directions': ['NLP', 'CV', 'Robotics']},
#  {'st': 'ST087013', 'year': 2022, 'directions': ['Web', 'NLP', 'DS']},
#  {'st': 'ST093636', 'year': 2022, 'directions': ['NLP', 'CV', 'Robotics']},
#  {'st': 'ST092111',
#   'year': 2022,
#   'directions': ['Web', 'NLP', 'CV', 'DS', 'Robotics', 'GameDev']},
#  {'st': 'ST090324', 'year': 2022, 'directions': ['NLP', 'CV', 'DS']},
#  {'st': 'ST086653', 'year': 2022, 'directions': ['Web', 'Time Series']},
#  {'st': 'ST076924',
#   'year': 2022,
#   'directions': ['NLP', 'CV', 'DS', 'GameDev']},
#  {'st': 'ST085077', 'year': 2022, 'directions': ['NLP', 'DS', 'GameDev']},
#  {'st': 'ST091075',
#   'year': 2022,
#   'directions': ['Web', 'NLP', 'CV', 'DS', 'GameDev']},
#  {'st': 'ST084946', 'year': 2022, 'directions': ['NLP', 'DS', 'GameDev']},
#  {'st': 'ST087271', 'year': 2022, 'directions': ['NLP', 'CV', 'Robotics']},
#  {'st': 'ST068997', 'year': 2022, 'directions': []},
#  {'st': 'ST091242', 'year': 2022, 'directions': ['CV', 'Robotics', 'GameDev']},
#  {'st': 'ST087006', 'year': 2022, 'directions': []},
#  {'st': 'ST087408',
#   'year': 2022,
#   'directions': ['Web', 'Time Series', 'DS', 'GameDev']},
#  {'st': 'ST087129',
#   'year': 2022,
#   'directions': ['NLP', 'CV', 'Time Series', 'DS', 'Robotics', 'GameDev']},
#  {'st': 'ST087725', 'year': 2022, 'directions': ['Web', 'NLP']},
#  {'st': 'ST068075', 'year': 2022, 'directions': ['DS', 'GameDev']},
#  {'st': 'ST086936',
#   'year': 2022,
#   'directions': ['CV', 'Time Series', 'DS', 'Robotics']},
#  {'st': 'ST087169', 'year': 2022, 'directions': ['Web']},
#  {'st': 'ST088277', 'year': 2022, 'directions': ['Robotics']},
#  {'st': 'ST087396', 'year': 2022, 'directions': ['CV', 'GameDev']},
#  {'st': 'ST090281', 'year': 2022, 'directions': ['Data Engeneering']},
#  {'st': 'ST088081', 'year': 2022, 'directions': ['GameDev']},
#  {'st': 'ST092157', 'year': 2022, 'directions': ['Web', 'Robotics']},
#  {'st': 'ST085954', 'year': 2022, 'directions': ['Web', 'CV', 'Robotics']},
#  {'st': 'ST091150 ', 'year': 2022, 'directions': ['Web', 'NLP', 'Robotics']},
#  {'st': 'ST087829', 'year': 2022, 'directions': []},
#  {'st': 'ST090695', 'year': 2022, 'directions': ['NLP', 'CV', 'DS']},
#  {'st': 'ST051995', 'year': 2022, 'directions': ['NLP', 'CV', 'GameDev']},
#  {'st': 'ST090881', 'year': 2022, 'directions': ['CV']},
#  {'st': 'ST087615', 'year': 2022, 'directions': ['Web']},
#  {'st': 'ST086855',
#   'year': 2022,
#   'directions': ['NLP', 'CV', 'Time Series', 'Robotics', 'GameDev']},
#  {'st': 'ST062283', 'year': 2022, 'directions': ['CV']},
#  {'st': 'ST062780', 'year': 2022, 'directions': ['Mobile Development']},
#  {'st': 'ST096581', 'year': 2022, 'directions': ['Web', 'DS', 'Robotics']},
#  {'st': 'ST087340', 'year': 2022, 'directions': ['CV', 'DS', 'Robotics']},
#  {'st': 'ST086869', 'year': 2022, 'directions': ['Web', 'NLP']},
#  {'st': 'ST086819', 'year': 2022, 'directions': ['CV']},
#  {'st': 'ST055825', 'year': 2022, 'directions': ['NLP']},
#  {'st': 'ST087103', 'year': 2022, 'directions': ['Web', 'CV', 'DS']},
#  {'st': 'ST088232', 'year': 2022, 'directions': ['NLP', 'CV']},
#  {'st': 'ST054614', 'year': 2021, 'directions': ['Robotics']},
#  {'st': 'ST076698', 'year': 2021, 'directions': ['Web', 'CV']},
#  {'st': 'ST077002',
#   'year': 2021,
#   'directions': ['Web', 'NLP', 'CV', 'Time Series', 'DS', 'GameDev']},
#  {'st': 'ST054632', 'year': 2021, 'directions': ['Web']},
#  {'st': 'ST078403', 'year': 2021, 'directions': ['NLP', 'CV', 'DS']},
#  {'st': 'ST077279', 'year': 2021, 'directions': ['Robotics', 'GameDev']},
#  {'st': 'ST088934',
#   'year': 2021,
#   'directions': ['NLP', 'CV', 'Time Series', 'DS', 'Robotics']},
#  {'st': 'ST088863',
#   'year': 2021,
#   'directions': ['Web', 'NLP', 'CV', 'Time Series', 'DS', 'Robotics']},
#  {'st': 'ST088937',
#   'year': 2021,
#   'directions': ['NLP', 'CV', 'Time Series', 'DS']},
#  {'st': 'ST088945',
#   'year': 2021,
#   'directions': ['NLP', 'CV', 'DS', 'Robotics']},
#  {'st': 'ST092158', 'year': 2021, 'directions': ['DS', 'Robotics', 'GameDev']},
#  {'st': 'ST076652', 'year': 2021, 'directions': ['DS']},
#  {'st': 'ST077004',
#   'year': 2021,
#   'directions': ['Web', 'DS', 'Robotics', 'GameDev']},
#  {'st': 'ST032721', 'year': 2021, 'directions': ['Web']},
#  {'st': 'ST054639', 'year': 2021, 'directions': ['NLP', 'DS']},
#  {'st': 'ST054731',
#   'year': 2021,
#   'directions': ['NLP', 'Robotics', 'GameDev']},
#  {'st': 'ST076645', 'year': 2021, 'directions': []},
#  {'st': 'ST054701', 'year': 2021, 'directions': ['Web']},
#  {'st': 'ST091906', 'year': 2021, 'directions': ['Robotics', 'GameDev']},
#  {'st': 'ST054652', 'year': 2021, 'directions': ['NLP']},
#  {'st': 'ST076363', 'year': 2021, 'directions': ['DS']},
#  {'st': 'ST077261',
#   'year': 2021,
#   'directions': ['Web', 'CV', 'Time Series', 'DS', 'Robotics', 'GameDev']},
#  {'st': 'ST054698', 'year': 2021, 'directions': ['NLP']},
#  {'st': 'ST076361', 'year': 2021, 'directions': []},
#  {'st': 'ST076009',
#   'year': 2021,
#   'directions': ['Web', 'NLP', 'Time Series', 'DS', 'Robotics']},
#  {'st': 'ST085956', 'year': 2021, 'directions': ['NLP']},
#  {'st': 'ST054678', 'year': 2021, 'directions': ['CV', 'Time Series']},
#  {'st': 'ST054648',
#   'year': 2021,
#   'directions': ['Web', 'NLP', 'CV', 'Time Series', 'DS']},
#  {'st': 'ST054620', 'year': 2021, 'directions': ['NLP']},
#  {'st': 'ST076649',
#   'year': 2021,
#   'directions': ['CV', 'Time Series', 'DS', 'Robotics']},
#  {'st': 'ST026596',
#   'year': 2021,
#   'directions': ['Web',
#    'NLP',
#    'CV',
#    'Time Series',
#    'DS',
#    'Robotics',
#    'GameDev']},
#  {'st': 'ST054636', 'year': 2021, 'directions': []},
#  {'st': 'ST076561',
#   'year': 2021,
#   'directions': ['Web', 'NLP', 'CV', 'DS', 'GameDev', 'Mobile Development']},
#  {'st': 'ST076801',
#   'year': 2021,
#   'directions': ['Web', 'NLP', 'CV', 'Time Series', 'DS']},
#  {'st': 'ST077321',
#   'year': 2021,
#   'directions': ['Web', 'NLP', 'CV', 'DS', 'Robotics', 'GameDev']},
#  {'st': 'ST080246',
#   'year': 2021,
#   'directions': ['Web', 'CV', 'DS', 'Robotics', 'GameDev']},
#  {'st': 'ST076930', 'year': 2021, 'directions': ['GameDev']},
#  {'st': 'ST076639', 'year': 2021, 'directions': ['CV']},
#  {'st': 'ST076582', 'year': 2021, 'directions': []},
#  {'st': 'ST076057', 'year': 2021, 'directions': []},
#  {'st': 'ST075589', 'year': 2021, 'directions': ['Web', 'NLP', 'CV']},
#  {'st': 'ST077267',
#   'year': 2021,
#   'directions': ['Web',
#    'NLP',
#    'CV',
#    'Time Series',
#    'GameDev',
#    'DS',
#    'Data Analysis']},
#  {'st': 'ST076206',
#   'year': 2021,
#   'directions': ['NLP', 'CV', 'Time Series', 'DS']},
#  {'st': 'ST076264', 'year': 2021, 'directions': ['NLP', 'CV', 'DS']},
#  {'st': 'ST076738', 'year': 2021, 'directions': []},
#  {'st': 'ST077367', 'year': 2021, 'directions': ['NLP', 'Time Series', 'DS']},
#  {'st': 'ST076704', 'year': 2021, 'directions': ['CV', 'GameDev', 'API']},
#  {'st': 'ST080521', 'year': 2021, 'directions': []},
#  {'st': 'ST077178', 'year': 2021, 'directions': ['Robotics', 'GameDev']},
#  {'st': 'ST077348',
#   'year': 2021,
#   'directions': ['Web',
#    'NLP',
#    'CV',
#    'Time Series',
#    'DS',
#    'Robotics',
#    'GameDev']},
#  {'st': 'ST080538', 'year': 2021, 'directions': []},
#  {'st': 'ST080559', 'year': 2021, 'directions': ['Web', 'NLP', 'DS']},
#  {'st': 'ST076307',
#   'year': 2021,
#   'directions': ['NLP', 'CV', 'Robotics', 'GameDev']},
#  {'st': 'ST076323', 'year': 2021, 'directions': ['NLP', 'CV', 'DS']},
#  {'st': 'ST076077', 'year': 2021, 'directions': []},
#  {'st': 'ST076013', 'year': 2021, 'directions': ['NLP', 'CV', 'Robotics']},
#  {'st': 'ST077128',
#   'year': 2021,
#   'directions': ['NLP', 'CV', 'Time Series', 'DS', 'GameDev']},
#  {'st': 'ST076522',
#   'year': 2021,
#   'directions': ['Web', 'NLP', 'CV', 'Time Series']},
#  {'st': 'ST076376', 'year': 2021, 'directions': ['Mobile Development']},
#  {'st': 'ST061936', 'year': 2020, 'directions': ['Robotics']},
#  {'st': 'ST068831', 'year': 2020, 'directions': ['NLP', 'CV', 'DS']},
#  {'st': 'ST046482',
#   'year': 2020,
#   'directions': ['Web', 'CV', 'Time Series', 'DS', 'GameDev']},
#  {'st': 'ST049209', 'year': 2020, 'directions': []},
#  {'st': 'ST050135',
#   'year': 2020,
#   'directions': ['Web', 'NLP', 'CV', 'DS', 'Robotics']},
#  {'st': 'ST048554', 'year': 2020, 'directions': ['CV', 'DS', 'GameDev']},
#  {'st': 'ST050084', 'year': 2020, 'directions': []},
#  {'st': 'ST050011', 'year': 2020, 'directions': ['Web', 'DS']},
#  {'st': 'ST049665', 'year': 2020, 'directions': []},
#  {'st': 'ST040311',
#   'year': 2020,
#   'directions': ['Web', 'CV', 'Time Series', 'GameDev']},
#  {'st': 'ST047526', 'year': 2020, 'directions': ['Web', 'GameDev']},
#  {'st': 'ST050094', 'year': 2020, 'directions': ['NLP', 'GameDev']},
#  {'st': 'ST049271', 'year': 2020, 'directions': ['NLP', 'GameDev']},
#  {'st': 'ST082013', 'year': 2020, 'directions': ['Web', 'Robotics']},
#  {'st': 'ST047123', 'year': 2020, 'directions': ['CV', 'DS', 'GameDev']},
#  {'st': 'ST046957',
#   'year': 2020,
#   'directions': ['Web', 'NLP', 'DS', 'Mobile Development']},
#  {'st': 'ST050602', 'year': 2020, 'directions': ['CV']},
#  {'st': 'ST040307', 'year': 2020, 'directions': ['Time Series', 'DS']},
#  {'st': 'ST046887', 'year': 2020, 'directions': ['CV']},
#  {'st': 'ST047160', 'year': 2020, 'directions': []},
#  {'st': 'ST070961', 'year': 2020, 'directions': ['DS', 'Robotics']},
#  {'st': 'ST048437', 'year': 2020, 'directions': ['Web', 'Robotics']},
#  {'st': 'ST068004', 'year': 2020, 'directions': []},
#  {'st': 'ST083432', 'year': 2020, 'directions': ['Web', 'NLP']},
#  {'st': 'ST073575', 'year': 2020, 'directions': ['NLP', 'DS']},
#  {'st': 'ST069751',
#   'year': 2020,
#   'directions': ['NLP', 'CV', 'Time Series', 'Robotics', 'GameDev']},
#  {'st': 'ST068979', 'year': 2020, 'directions': ['Robotics']},
#  {'st': 'ST067884', 'year': 2020, 'directions': ['Time Series']},
#  {'st': 'ST069386',
#   'year': 2020,
#   'directions': ['Web', 'CV', 'Time Series', 'DS', 'GameDev']},
#  {'st': 'ST072326', 'year': 2020, 'directions': ['Web', 'CV', 'Time Series']},
#  {'st': 'ST068988',
#   'year': 2020,
#   'directions': ['CV', 'Time Series', 'DS', 'Robotics']},
#  {'st': 'ST069557', 'year': 2020, 'directions': ['NLP', 'CV', 'DS']},
#  {'st': 'ST064146', 'year': 2020, 'directions': ['Web', 'Design']},
#  {'st': 'ST069664',
#   'year': 2020,
#   'directions': ['Web', 'CV', 'Time Series', 'DS']},
#  {'st': 'ST069509', 'year': 2020, 'directions': ['Web', 'NLP', 'Time Series']},
#  {'st': 'ST069505', 'year': 2020, 'directions': ['Time Series', 'DS']},
#  {'st': 'ST069378', 'year': 2020, 'directions': ['Time Series', 'DS']},
#  {'st': 'ST072069', 'year': 2020, 'directions': ['Web', 'NLP', 'Robotics']},
#  {'st': 'ST068463', 'year': 2020, 'directions': ['Robotics']},
#  {'st': 'ST064271', 'year': 2020, 'directions': ['DS']},
#  {'st': 'ST044418', 'year': 2020, 'directions': ['Web', 'NLP', 'Robotics']},
#  {'st': 'ST069410', 'year': 2020, 'directions': ['NLP']},
#  {'st': 'ST068199', 'year': 2020, 'directions': ['DS', 'Robotics']},
#  {'st': 'ST061931', 'year': 2020, 'directions': []},
#  {'st': 'ST068789', 'year': 2020, 'directions': ['Robotics', 'GameDev']},
#  {'st': 'ST068262',
#   'year': 2020,
#   'directions': ['NLP', 'CV', 'Time Series', 'DS', 'Robotics', 'GameDev']},
#  {'st': 'ST071609',
#   'year': 2020,
#   'directions': ['NLP', 'DS', 'Robotics', 'GameDev']},
#  {'st': 'ST069390', 'year': 2020, 'directions': ['NLP', 'Robotics']},
#  {'st': 'ST069533',
#   'year': 2020,
#   'directions': ['Web', 'NLP', 'CV', 'GameDev']},
#  {'st': 'ST068847', 'year': 2020, 'directions': ['Web', 'NLP', 'DS']},
#  {'st': 'ST082348', 'year': 2020, 'directions': []},
#  {'st': 'ST068048', 'year': 2020, 'directions': ['CV', 'Robotics', 'GameDev']},
#  {'st': 'ST055946', 'year': 2020, 'directions': ['DS']},
#  {'st': 'ST068144', 'year': 2020, 'directions': ['DS', 'GameDev']},
#  {'st': 'ST069657', 'year': 2020, 'directions': ['Web', 'DS']},
#  {'st': 'ST069407', 'year': 2020, 'directions': ['Web', 'Data Analysis']},
#  {'st': 'ST068845', 'year': 2020, 'directions': []},
#  {'st': 'ST068737', 'year': 2020, 'directions': ['DS', 'GameDev']},
#  {'st': 'ST069501',
#   'year': 2020,
#   'directions': ['Web', 'NLP', 'CV', 'DS', 'Robotics']},
#  {'st': 'ST068617',
#   'year': 2020,
#   'directions': ['Web', 'Time Series', 'GameDev', 'Data Analysis']},
#  {'st': 'ST069145', 'year': 2020, 'directions': ['NLP', 'CV']},
#  {'st': 'ST082478',
#   'year': 2020,
#   'directions': ['Time Series', 'GameDev', 'low_level development']},
#  {'st': 'ST063763',
#   'year': 2020,
#   'directions': ['Web', 'CV', 'DS', 'low_level development']},
#  {'st': 'ST069430',
#   'year': 2020,
#   'directions': ['Web', 'DS', 'Robotics', 'GameDev']},
#  {'st': 'ST055663',
#   'year': 2020,
#   'directions': ['NLP', 'Time Series', 'GameDev']},
#  {'st': 'ST068601', 'year': 2020, 'directions': ['Web', 'CV', 'GameDev']},
#  {'st': 'ST068421',
#   'year': 2020,
#   'directions': ['NLP', 'CV', 'Robotics', 'GameDev']},
#  {'st': 'ST070068', 'year': 2020, 'directions': ['DS']},
#  {'st': 'ST062258',
#   'year': 2019,
#   'directions': ['Web', 'Time Series', 'DS', 'Robotics']},
#  {'st': 'ST063116',
#   'year': 2019,
#   'directions': ['Web', 'NLP', 'Time Series', 'DS', 'Robotics']},
#  {'st': 'ST063773',
#   'year': 2019,
#   'directions': ['Web', 'Time Series', 'DS', 'GameDev']},
#  {'st': 'ST063775', 'year': 2019, 'directions': ['NLP', 'Robotics']},
#  {'st': 'ST064147',
#   'year': 2019,
#   'directions': ['NLP', 'Time Series', 'DS', 'Robotics']},
#  {'st': 'ST064150',
#   'year': 2019,
#   'directions': ['NLP',
#    'Robotics',
#    'GameDev',
#    'Design',
#    'programming language development']},
#  {'st': 'ST064152', 'year': 2019, 'directions': []},
#  {'st': 'ST063118',
#   'year': 2019,
#   'directions': ['Web', 'NLP', 'Time Series', 'DS', 'GameDev']},
#  {'st': 'ST054491',
#   'year': 2019,
#   'directions': ['Web', 'Time Series', 'DS', 'GameDev']},
#  {'st': 'ST064143', 'year': 2019, 'directions': ['Web', 'NLP', 'Robotics']},
#  {'st': 'ST074128', 'year': 2019, 'directions': ['Time Series', 'DS']},
#  {'st': 'ST064149',
#   'year': 2019,
#   'directions': ['Web', 'Time Series', 'DS', 'Robotics', 'Data Analysis']},
#  {'st': 'ST061609',
#   'year': 2019,
#   'directions': ['Web', 'NLP', 'Time Series', 'DS', 'GameDev']},
#  {'st': 'ST062274', 'year': 2019, 'directions': ['NLP', 'Time Series', 'DS']},
#  {'st': 'ST064153',
#   'year': 2019,
#   'directions': ['Web', 'Time Series', 'DS', 'Robotics', 'GameDev']},
#  {'st': 'ST062269', 'year': 2019, 'directions': ['Robotics']},
#  {'st': 'ST063756', 'year': 2019, 'directions': ['Robotics']},
#  {'st': 'ST063115', 'year': 2019, 'directions': ['NLP', 'Robotics']},
#  {'st': 'ST073936', 'year': 2019, 'directions': ['NLP']},
#  {'st': 'ST053226',
#   'year': 2019,
#   'directions': ['Web', 'NLP', 'Time Series', 'DS']},
#  {'st': 'ST051992',
#   'year': 2019,
#   'directions': ['Web', 'NLP', 'Time Series', 'DS', 'Robotics', 'GameDev']},
#  {'st': 'ST063770', 'year': 2019, 'directions': ['Web', 'Time Series', 'DS']},
#  {'st': 'ST064148', 'year': 2019, 'directions': ['Web', 'Time Series', 'DS']},
#  {'st': 'ST064151',
#   'year': 2019,
#   'directions': ['Time Series', 'DS', 'GameDev']},
#  {'st': 'ST063214', 'year': 2019, 'directions': ['Time Series', 'DS']},
#  {'st': 'ST061938',
#   'year': 2019,
#   'directions': ['NLP', 'Time Series', 'DS', 'Robotics', 'GameDev']},
#  {'st': 'ST063112', 'year': 2019, 'directions': ['Web', 'NLP', 'GameDev']},
#  {'st': 'ST063767',
#   'year': 2019,
#   'directions': ['Web', 'Time Series', 'DS', 'GameDev']},
#  {'st': 'ST061671',
#   'year': 2019,
#   'directions': ['Web', 'Robotics', 'GameDev']},
#  {'st': 'ST064732',
#   'year': 2019,
#   'directions': ['NLP', 'Time Series', 'DS', 'Robotics']},
#  {'st': 'ST063769',
#   'year': 2019,
#   'directions': ['NLP', 'Time Series', 'DS', 'Robotics', 'GameDev']},
#  {'st': 'ST063113', 'year': 2019, 'directions': ['Robotics']},
#  {'st': 'ST052001',
#   'year': 2019,
#   'directions': ['Web',
#    'NLP',
#    'Time Series',
#    'DS',
#    'Robotics',
#    'Data Analysis']},
#  {'st': 'ST063119',
#   'year': 2019,
#   'directions': ['Web', 'low_level development']},
#  {'st': 'ST064145',
#   'year': 2019,
#   'directions': ['NLP', 'Robotics', 'GameDev']},
#  {'st': 'ST061934', 'year': 2019, 'directions': ['Mobile Development']},
#  {'st': 'ST063111', 'year': 2019, 'directions': ['Web', 'Time Series', 'DS']},
#  {'st': 'ST063768', 'year': 2019, 'directions': ['NLP']},
#  {'st': 'ST064730',
#   'year': 2019,
#   'directions': ['Time Series', 'DS', 'Robotics']},
#  {'st': 'ST064140',
#   'year': 2019,
#   'directions': ['Web', 'NLP', 'Time Series', 'DS', 'Robotics']},
#  {'st': 'ST061752',
#   'year': 2019,
#   'directions': ['Web', 'Time Series', 'DS', 'Robotics']},
#  {'st': 'ST064142', 'year': 2019, 'directions': ['NLP', 'Time Series', 'DS']},
#  {'st': 'ST054366',
#   'year': 2019,
#   'directions': ['Time Series', 'DS', 'Robotics', 'Mobile Development']},
#  {'st': 'ST063772', 'year': 2019, 'directions': ['NLP', 'Time Series', 'DS']},
#  {'st': 'ST064731', 'year': 2019, 'directions': ['NLP', 'GameDev']},
#  {'st': 'ST064144', 'year': 2019, 'directions': ['NLP', 'Robotics']},
#  {'st': 'ST061362',
#   'year': 2019,
#   'directions': ['Time Series', 'DS', 'Design']},
#  {'st': 'ST061177',
#   'year': 2019,
#   'directions': ['Web', 'NLP', 'Time Series', 'DS']},
#  {'st': 'ST054461',
#   'year': 2019,
#   'directions': ['NLP', 'Time Series', 'DS', 'Robotics']},
#  {'st': 'ST063110',
#   'year': 2019,
#   'directions': ['Web', 'NLP', 'Time Series', 'DS', 'Robotics', 'DL']},
#  {'st': 'ST064738',
#   'year': 2019,
#   'directions': ['Web', 'NLP', 'Time Series', 'DS']}]

# %%
df.to_excel('data_with_score_directions.xlsx', index=False)
