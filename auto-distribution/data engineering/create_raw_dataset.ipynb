# %% [markdown]
# # **Описание:**
# -Описание задачи: Соединить данные опросов за несколько лет в единую таблицу
#
# -Ожидаемый результат: Таблица с данными опросов за 2019-2023 год (6 потоков)
#
# -Предпосылки для задачи: Исправление результатов работы [issue #6](edu_practice/auto_distribution#6)
#
# -Краткий вывод: Получена таблица, пригодная для дальнейшего анализа и решения задач по DS

# %% [markdown]
# # **План на исследование:**
#
# 1.   Проверить соответствие вопросов и ответов в таблице
# 2.   Принять решение : исправить ошибки или заново склеить таблицу
# 3.   Исправить таблицу

# %% [markdown]
# # **Шаги исследования:**
#
# ## Шаг 1 - Проверить соответствие вопросов и ответов в таблице:
# Были выявлены не системные сдвиги данных. Например, первые столбцы с ответами за 2019 год.
#
# ## Шаг 2 - Принять решение : исправить ошибки или заново склеить таблицу
# Логику смещений выявить не удалось.
#
# Было выявлено неоправданное отсутствие ряда вопросов, данные по которым присутствовали во всех опросах 2019-2023.
#
# Было принято решение заново склеить данные.
#
# ## Шаг 3 - Исправить таблицу:
#
# 1.  *В столбце отметка времени обнаружен 21 пропуск.*
#
#   Все эти значения относятся к опросу за 2020 год(у бакалавров есть даты, у магистрантов - нет). Заполнено значением относящимся к периоду опроса(01.09.2020 3:04:53).
#
# 2.  *В таблицу были возвращены колонки:*
#         Выберете интересующие Вас роли, в  IT [Бизнес и системный анализ]
#         Выберете интересующие Вас роли, в  IT [Дизайн UX / UI и проектирование интерфейсов]
#         Выберете интересующие Вас роли, в  IT [Анализ и инженерия данных]
#         и др.
#
# 3. *В 2019 был вопрос:* Выберете интересующие Вас роли, в  IT [программирование(разработка)], а в следующих вопросах было разделение на frontend и backend.
#
#   Заполнила обе колонки в итоговой таблице ответами на вопрос про программирование.
#
# 4. *При склейке данных в 2019 году получаем 4 пустых столбца:*
#
#           Выберете интересующие вас роли...
#             -  анализ и инженерия данных
#             оставляю пустым
#
#           Выберете интересующие вас направления...
#             - анализ временных рядов
#             - анализ таблиц
#             заполнила значениями из [Прогнозный анализ данных (статистика и машинное обучение)]
#
#             - анализ изображений/видео
#             оставляю пустым
#
# 5. *До 2022 года нет вопроса :*
#
#         Оцените Ваши знания в области IT [Data Science and Machine Learning]
#     Возможно данных для анализа этого вопроса будет недостаточно, тогда можно будет принять решение об удалении данного столбца.
#
#
# 6. *В опросе за 2019 год нет вопросов:*
#         SoftSkills [Self management]
#               - оставила значения пустыми
#         SoftSkills [Коммуникации]
#               - заполнила значениями: работа в команде
#
# 7. *Исправлены опечатки в столбце с ST*
#
#     Удалены лишние пробелы в начале записи и исправлены опечатки(лишняя цифра в ST и опечатка SR вместо ST)
#
# 8. *Ответы приведены к единому виду*
#
#     * "0  Не знаю" заменено на "0 - Не знаю"
#
#     * "Хочу поучаствовать в проектах в данной роли и развиваться дальше в эту область" заменено на "Хочу поучаствовать в проекте в этой роли и развиваться дальше в эту область"

# %% [markdown]
# # **Выводы:**
# Таблица, полученная в результате работы, носит более полный характер, так как были минимизированы потери данных. Это позволит получить более качественное решение задач проекта и получить репрезентативные выводы по вопросам аналитики.
