# %% [markdown]
# # **Описание:**
# -Описание задачи: Привести к единому виду шаблонные ответы прошлых лет
#
# -Ожидаемый результат: Таблица с едиными данными опросов за 2019-2023 год (6 потоков)
#
# -Предпосылки для задачи: Исправление результатов работы [issue #39](https://gitlab.com/edu_practice/auto_distribution/-/issues/39)
# с прицелом на задачу [issue #27](https://gitlab.com/edu_practice/auto_distribution/-/issues/27)
#
# -Краткий вывод: Получена таблица, пригодная для дальнейшего анализа и решения задач по DS

# %% [markdown]
# # **План на исследование:**
#
# 1.   Изучить колонки, требующие исправления
# 2.   Исправить таблицу

# %% [markdown]
# # **Шаги исследования:**
#
# ## Шаг 1 - Изучить колонки, требующие исправления :
#
# Выберете интересные для вас направление проекта (в направлении проекта могут быть все роли, указанные выше) [Разработка веб-сервисов (сайты, сервисы)]
#
# Выберете интересные для вас направление проекта (в направлении проекта могут быть все роли, указанные выше) [Анализ текстов и поисковые движки]
#
# Выберете интересные для вас направление проекта (в направлении проекта могут быть все роли, указанные выше) [Анализ временных рядов]
#
# Выберете интересные для вас направление проекта (в направлении проекта могут быть все роли, указанные выше) [Анализ табличных данных]
#
# Выберете интересные для вас направление проекта (в направлении проекта могут быть все роли, указанные выше) [Робототехника (оборудование, теория управления, техническое зрение, интерфейсы)]
#
# Выберете интересные для вас направление проекта (в направлении проекта могут быть все роли, указанные выше) [Gamedev]
#
# ## Шаг 2 - Исправить таблицу:
#
# В данных колонках вариант "Хочу поучаствовать в проектах и развиваться дальше в данную область" заменён на "Хочу поучаствовать в проекте по данной области в роли, выбранной ранее", так как они несут одинаковую смысловую нагрузку(оставлен вариант использовавшийся в опросе за 2023 год).
# Заменены значения 68 ячеек.

# %% [markdown]
# # **Выводы:**
# Таблица, полученная в результате работы пригодна для использования в задаче с кодированием категорий.
